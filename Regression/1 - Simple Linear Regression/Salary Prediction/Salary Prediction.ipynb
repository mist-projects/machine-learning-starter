# %% [markdown]
# # **Problem Statement :**
# Predict salaty based on number of years experience

# %% [markdown]
# # **Step  1 : Import Libraries**

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # **Step 2 : Import Dataset**

# %%
dataset = pd.read_csv('Salary_Data.csv')
X = dataset.iloc[:, :-1].values 
y = dataset.iloc[:, -1].values # -1 represents last column

# %% [markdown]
# # **Step 3 : Visualize dataset**

# %%
dataset.head(4)
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0

# %%
sns.jointplot(x = 'YearsExperience', y = 'Salary', data = dataset)

# %%
sns.jointplot(x = 'Salary', y = 'YearsExperience', data = dataset)

# %%
sns.pairplot(dataset)

# %%
sns.lmplot(x = 'YearsExperience', y = 'Salary', data = dataset)

# %%
sns.lmplot(x = 'Salary', y = 'YearsExperience', data = dataset)

# %% [markdown]
# # **Step 4 : Split into Training and Test dataset**

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %% [markdown]
# # **Step 5 : Train the model**

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print('Linear Model Coeff (m):', regressor.coef_)
print('Linear Model Coeff (b):', regressor.intercept_)
# Out:
# Linear Model Coeff (m): [9312.57512673]
# Linear Model Coeff (b): 26780.09915062818

# %% [markdown]
# # **Step 6 : Test the model**

# %%
y_pred = regressor.predict(X_test)
print(y_pred)
# Out:
# [ 40748.96184072 122699.62295594  64961.65717022  63099.14214487
#  115249.56285456 107799.50275317]

# %%
plt.scatter(X_train, y_train, color = 'red')
plt.plot(X_train, regressor.predict(X_train), color = 'blue')
plt.title('Salary vs Experience (Training Set)')
plt.xlabel('Years Of Experience')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# # **Step 7 : Visualize Test set results**

# %%
plt.scatter(X_test, y_test, color = 'red')
plt.plot(X_train, regressor.predict(X_train), color = 'blue')
plt.title('Salary vs Experience (Training Set)')
plt.xlabel('Years Of Experience')
plt.ylabel('Salary')
plt.show()

# %%
print(regressor.predict([[12]]))
# Out:
# [138531.00067138]
