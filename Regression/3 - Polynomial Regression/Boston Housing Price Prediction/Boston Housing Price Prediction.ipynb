# %% [markdown]
# # **Problem Statement :**
# This dataset is created for prediction of the Boston Housing Price

# %% [markdown]
# # **Step 1 : Import Libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import sklearn

# %%
print(np.__version__)
print(pd.__version__)
import sys
print(sys.version)
print(sklearn.__version__)
# Out:
# 1.18.5
# 1.1.4
# 3.6.9 (default, Oct  8 2020, 12:12:24)
# [GCC 8.4.0]
# 0.22.2.post1

# %% [markdown]
# # **Step 2 : Example of Polynomial equation $$y = X^3 + 100 + \epsilon$$**

# %%
# Without noise

np.random.seed(42)
n_samples = 100

X = np.linspace(0, 10, 100) # 100 numbers between 0 and 10
print(X)

y = X ** 3 + 100

plt.figure(figsize=(10,8));
plt.scatter(X, y);
# Out:
# [ 0.          0.1010101   0.2020202   0.3030303   0.4040404   0.50505051
#   0.60606061  0.70707071  0.80808081  0.90909091  1.01010101  1.11111111
#   1.21212121  1.31313131  1.41414141  1.51515152  1.61616162  1.71717172
#   1.81818182  1.91919192  2.02020202  2.12121212  2.22222222  2.32323232
#   2.42424242  2.52525253  2.62626263  2.72727273  2.82828283  2.92929293
#   3.03030303  3.13131313  3.23232323  3.33333333  3.43434343  3.53535354
#   3.63636364  3.73737374  3.83838384  3.93939394  4.04040404  4.14141414
#   4.24242424  4.34343434  4.44444444  4.54545455  4.64646465  4.74747475
#   4.84848485  4.94949495  5.05050505  5.15151515  5.25252525  5.35353535
#   5.45454545  5.55555556  5.65656566  5.75757576  5.85858586  5.95959596
#   6.06060606  6.16161616  6.26262626  6.36363636  6.46464646  6.56565657
#   6.66666667  6.76767677  6.86868687  6.96969697  7.07070707  7.17171717
#   7.27272727  7.37373737  7.47474747  7.57575758  7.67676768  7.77777778
#   7.87878788  7.97979798  8.08080808  8.18181818  8.28282828  8.38383838
#   8.48484848  8.58585859  8.68686869  8.78787879  8.88888889  8.98989899
#   9.09090909  9.19191919  9.29292929  9.39393939  9.49494949  9.5959596
#   9.6969697   9.7979798   9.8989899  10.        ]

# %%
# With noise
np.random.seed(42)
n_samples = 100

X = np.linspace(0, 10, 100) # 100 numbers between 0 and 10
print(X)
print(X.shape)

rng = np.random.randn(n_samples) * 100
print(rng) # some noise

y = X ** 3 + 100 + rng

plt.figure(figsize=(10,8));
plt.scatter(X, y);
# Out:
# [ 0.          0.1010101   0.2020202   0.3030303   0.4040404   0.50505051
#   0.60606061  0.70707071  0.80808081  0.90909091  1.01010101  1.11111111
#   1.21212121  1.31313131  1.41414141  1.51515152  1.61616162  1.71717172
#   1.81818182  1.91919192  2.02020202  2.12121212  2.22222222  2.32323232
#   2.42424242  2.52525253  2.62626263  2.72727273  2.82828283  2.92929293
#   3.03030303  3.13131313  3.23232323  3.33333333  3.43434343  3.53535354
#   3.63636364  3.73737374  3.83838384  3.93939394  4.04040404  4.14141414
#   4.24242424  4.34343434  4.44444444  4.54545455  4.64646465  4.74747475
#   4.84848485  4.94949495  5.05050505  5.15151515  5.25252525  5.35353535
#   5.45454545  5.55555556  5.65656566  5.75757576  5.85858586  5.95959596
#   6.06060606  6.16161616  6.26262626  6.36363636  6.46464646  6.56565657
#   6.66666667  6.76767677  6.86868687  6.96969697  7.07070707  7.17171717
#   7.27272727  7.37373737  7.47474747  7.57575758  7.67676768  7.77777778
#   7.87878788  7.97979798  8.08080808  8.18181818  8.28282828  8.38383838
#   8.48484848  8.58585859  8.68686869  8.78787879  8.88888889  8.98989899
#   9.09090909  9.19191919  9.29292929  9.39393939  9.49494949  9.5959596
#   9.6969697   9.7979798   9.8989899  10.        ]
# (100,)
# [  49.6714153   -13.82643012   64.76885381  152.30298564  -23.41533747
#   -23.41369569  157.92128155   76.74347292  -46.94743859   54.25600436
#   -46.34176928  -46.57297536   24.19622716 -191.32802447 -172.49178325
#   -56.22875292 -101.28311203   31.42473326  -90.80240755 -141.23037013
#   146.56487689  -22.57763005    6.75282047 -142.47481862  -54.43827245
#    11.09225897 -115.09935774   37.56980183  -60.06386899  -29.16937498
#   -60.17066122  185.22781845   -1.34972247 -105.7710929    82.25449121
#  -122.084365     20.8863595  -195.96701239 -132.81860489   19.68612359
#    73.846658     17.13682812  -11.56482824  -30.11036956 -147.85219904
#   -71.98442084  -46.0638771   105.71222262   34.36182896 -176.30401554
#    32.40839694  -38.50822804  -67.69220003   61.16762888  103.09995225
#    93.12801191  -83.92175232  -30.92123759   33.12634314   97.55451271
#   -47.91742378  -18.56589767 -110.6334974  -119.62066241   81.25258224
#   135.62400286   -7.20101216  100.35328979   36.1636025   -64.51197546
#    36.13956055  153.80365665   -3.58260391  156.46436558 -261.97451041
#    82.19025044    8.70470682  -29.90073505    9.17607765 -198.75689146
#   -21.96718878   35.71125715  147.78940447  -51.82702183  -80.84936029
#   -50.17570436   91.54021177   32.87511097  -52.97602038   51.32674331
#     9.70775493   96.86449905  -70.20530939  -32.76621466  -39.21081531
#  -146.35149481   29.61202771   26.10552722    0.51134566  -23.45871334]

# %% [markdown]
# # **Step 3 : Linear Regression**

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

lr = LinearRegression()
#print ('X : \n', X)
#print ('X.reshape(-1, 1) : \n', X.reshape(-1, 1)) # -1 will not define any rows. It will take all data in X
#print('y : \n', y)

#print ('Shape 1 : ', X.reshape(-1, 1).shape, 'Shape 2 : ', y.shape)
lr.fit(X.reshape(-1, 1), y)
model_pred = lr.predict(X.reshape(-1,1))

plt.figure(figsize=(10,8));
plt.scatter(X, y);
plt.plot(X, model_pred);
print(r2_score(y, model_pred))
# Out:
# 0.7643394574930141

# %% [markdown]
# # **Step 4 : Polynomial Regression**

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
poly_reg = PolynomialFeatures(degree=2)
X_poly = poly_reg.fit_transform(X.reshape(-1, 1))

# %%
X[:5]
# Out:
# array([0.       , 0.1010101, 0.2020202, 0.3030303, 0.4040404])

# %%
X_poly[:5]
# Out:
# array([[1.        , 0.        , 0.        ],
#        [1.        , 0.1010101 , 0.01020304],
#        [1.        , 0.2020202 , 0.04081216],
#        [1.        , 0.3030303 , 0.09182736],
#        [1.        , 0.4040404 , 0.16324865]])

# %%
degree_three = PolynomialFeatures(degree=3)
example = degree_three.fit_transform(X.reshape(-1, 1))

# %%
example[:5]
# Out:
# array([[1.        , 0.        , 0.        , 0.        ],
#        [1.        , 0.1010101 , 0.01020304, 0.00103061],
#        [1.        , 0.2020202 , 0.04081216, 0.00824488],
#        [1.        , 0.3030303 , 0.09182736, 0.02782647],
#        [1.        , 0.4040404 , 0.16324865, 0.06595905]])

# %%
res = np.array([0, 1, 2, 3, 4, 5])
res
# Out:
# array([0, 1, 2, 3, 4, 5])

# %%
# Simple illustration with degree 2 
res_two = poly_reg.fit_transform(res.reshape(-1, 1))
res_two
# Out:
# array([[ 1.,  0.,  0.],
#        [ 1.,  1.,  1.],
#        [ 1.,  2.,  4.],
#        [ 1.,  3.,  9.],
#        [ 1.,  4., 16.],
#        [ 1.,  5., 25.]])

# %%
# Simple illustration with degree 3
res_three = degree_three.fit_transform(res.reshape(-1, 1))
res_three
# Out:
# array([[  1.,   0.,   0.,   0.],
#        [  1.,   1.,   1.,   1.],
#        [  1.,   2.,   4.,   8.],
#        [  1.,   3.,   9.,  27.],
#        [  1.,   4.,  16.,  64.],
#        [  1.,   5.,  25., 125.]])

# %%
lin_reg_2 = LinearRegression()
lin_reg_2.fit(X_poly, y.reshape(-1, 1))
y_pred = lin_reg_2.predict(X_poly)

# %%
plt.figure(figsize=(10,8));
plt.scatter(X, y);
plt.plot(X, y_pred);
print(r2_score(y, y_pred))
# Out:
# 0.9173858308909386

# %% [markdown]
# # **Step 5 : Boston Housing Dataset**

# %%
# !wget https://archive.ics.uci.edu/ml/machine-learning-databases/housing/housing.data
# Out:
# --2020-11-27 10:08:45--  https://archive.ics.uci.edu/ml/machine-learning-databases/housing/housing.data
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 49082 (48K) [application/x-httpd-php]
# Saving to: ‘housing.data.1’
#
# housing.data.1      100%[===================>]  47.93K   182KB/s    in 0.3s
#
# 2020-11-27 10:08:46 (182 KB/s) - ‘housing.data.1’ saved [49082/49082]

# %%
df_boston = pd.read_csv('housing.data', delim_whitespace=True, header=None)
df_boston.columns = ['CRIM', 'ZN' , 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 
              'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']
#sns.pairplot(df_boston, size=1.5);

# %%
pd.options.display.float_format = "{:,.2f}".format
df_boston.corr()
# Out:
#          CRIM    ZN  INDUS  CHAS   NOX  ...   TAX  PTRATIO     B  LSTAT  MEDV
# CRIM     1.00 -0.20   0.41 -0.06  0.42  ...  0.58     0.29 -0.39   0.46 -0.39
# ZN      -0.20  1.00  -0.53 -0.04 -0.52  ... -0.31    -0.39  0.18  -0.41  0.36
# INDUS    0.41 -0.53   1.00  0.06  0.76  ...  0.72     0.38 -0.36   0.60 -0.48
# CHAS    -0.06 -0.04   0.06  1.00  0.09  ... -0.04    -0.12  0.05  -0.05  0.18
# NOX      0.42 -0.52   0.76  0.09  1.00  ...  0.67     0.19 -0.38   0.59 -0.43
# RM      -0.22  0.31  -0.39  0.09 -0.30  ... -0.29    -0.36  0.13  -0.61  0.70
# AGE      0.35 -0.57   0.64  0.09  0.73  ...  0.51     0.26 -0.27   0.60 -0.38
# DIS     -0.38  0.66  -0.71 -0.10 -0.77  ... -0.53    -0.23  0.29  -0.50  0.25
# RAD      0.63 -0.31   0.60 -0.01  0.61  ...  0.91     0.46 -0.44   0.49 -0.38
# TAX      0.58 -0.31   0.72 -0.04  0.67  ...  1.00     0.46 -0.44   0.54 -0.47
# PTRATIO  0.29 -0.39   0.38 -0.12  0.19  ...  0.46     1.00 -0.18   0.37 -0.51
# B       -0.39  0.18  -0.36  0.05 -0.38  ... -0.44    -0.18  1.00  -0.37  0.33
# LSTAT    0.46 -0.41   0.60 -0.05  0.59  ...  0.54     0.37 -0.37   1.00 -0.74
# MEDV    -0.39  0.36  -0.48  0.18 -0.43  ... -0.47    -0.51  0.33  -0.74  1.00
#
# [14 rows x 14 columns]

# %%
X_boston = df_boston['DIS'].values
y_boston = df_boston['NOX'].values

# %%
plt.figure(figsize=(12,8))
plt.scatter(X_boston, y_boston);

# %% [markdown]
# # **Step 6 : Linear Equation**

# %%
lr = LinearRegression()
lr.fit(X_boston.reshape(-1, 1), y_boston)
model_pred = lr.predict(X_boston.reshape(-1,1))

plt.figure(figsize=(12,8))
plt.scatter(X_boston, y_boston);
plt.plot(X_boston, model_pred);
print("R^2 score = {:.2f}".format(r2_score(y_boston, model_pred)))
# Out:
# R^2 score = 0.59

# %% [markdown]
# # **Step 7 : Quadratic Equation**

# %%
poly_reg = PolynomialFeatures(degree=2)
X_poly_b = poly_reg.fit_transform(X_boston.reshape(-1, 1))
lin_reg_2 = LinearRegression()

# %%
lin_reg_2.fit(X_poly_b, y_boston)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print ('X_boston.min() :', X_boston.min(), 'X_boston.max() : ', X_boston.max())
X_fit = np.arange(X_boston.min(), X_boston.max(), 1)[:, np.newaxis]
# Out:
# X_boston.min() : 1.1296 X_boston.max() :  12.1265

# %%
X_fit
# Out:
# array([[ 1.1296],
#        [ 2.1296],
#        [ 3.1296],
#        [ 4.1296],
#        [ 5.1296],
#        [ 6.1296],
#        [ 7.1296],
#        [ 8.1296],
#        [ 9.1296],
#        [10.1296],
#        [11.1296]])

# %%
y_pred = lin_reg_2.predict(poly_reg.fit_transform(X_fit.reshape(-1,1)))

# %%
plt.figure(figsize=(10,8));
plt.scatter(X_boston, y_boston);
plt.plot(X_fit, y_pred);
print("R^2 score = {:.2f}".format(r2_score(y_boston, 
                                          lin_reg_2.predict(X_poly_b))))
# Out:
# R^2 score = 0.70

# %% [markdown]
# # **Step 8 : Cubic Equation**

# %%
poly_reg = PolynomialFeatures(degree=3)
X_poly_b = poly_reg.fit_transform(X_boston.reshape(-1, 1))
lin_reg_3 = LinearRegression()

# %%
lin_reg_3.fit(X_poly_b, y_boston)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
X_fit = np.arange(X_boston.min(), X_boston.max(), 1)[:, np.newaxis]

# %%
y_pred = lin_reg_3.predict(poly_reg.fit_transform(X_fit.reshape(-1,1)))

# %%
plt.figure(figsize=(10,8));
plt.scatter(X_boston, y_boston);
plt.plot(X_fit, y_pred);
print("R^2 score = {:.2f}".format(r2_score(y_boston, 
                                          lin_reg_3.predict(X_poly_b))))
# Out:
# R^2 score = 0.71
